# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

# MNIST data fetch karne ki koshish karein
from sklearn.datasets import fetch_openml
print("Fetching MNIST data... (Isme thoda time lag sakta hai)")

mnist = fetch_openml('mnist_784', as_frame=False)
X, y = mnist.data, mnist.target

print(f"Data shape: {X.shape}")
print("Mubarak ho! Aapka classification environment set hai.")
# Out:
# Fetching MNIST data... (Isme thoda time lag sakta hai)
# Data shape: (70000, 784)
# Mubarak ho! Aapka classification environment set hai.
